# %% [markdown]
# # Stock Price Predictor
# ##### By D Dheeraj Roy

# %% [markdown]
# ## Importing libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime

# %% [markdown]
# ## Import datasets

# %%
from yahoo_fin import stock_info
ticker = input('Enter ticker: ')
df = stock_info.get_data(ticker)
df = df.reset_index()
df.rename(columns={'index': 'datetime'}, inplace=True)
df['datetime'] = df['datetime'].apply(lambda x: datetime.timestamp(x))
X = np.delete(df.iloc[:, 0:-2].values, obj=[2, 3, 4, 5], axis=1)
y = df.iloc[:, 4].values
# Out:
# Enter ticker: googl

# %% [markdown]
# ## Splitting dataset for training and testing

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# %% [markdown]
# ## Training model

# %%
from sklearn.ensemble import RandomForestRegressor
from datetime import datetime
model = RandomForestRegressor(n_estimators=5)
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
print('datetime\t\ty_test\ty_pred')
print('-'*38)
for i, j, k in zip(X_test[:, 0], y_test, y_pred):
    print(f'{datetime.fromtimestamp(i)}\t{round(j, 2)}\t{round(k, 2)}')
# Out:
# datetime		y_test	y_pred
# --------------------------------------
# 2008-12-22 00:00:00	7.44	7.89
# 2008-05-02 00:00:00	14.55	14.98
# 2015-06-05 00:00:00	27.48	27.62
# 2015-05-13 00:00:00	26.97	26.69
# 2013-12-13 00:00:00	26.55	27.0
# 2004-11-16 00:00:00	4.32	4.5
# 2014-10-29 00:00:00	27.92	27.99
# 2014-06-18 00:00:00	28.03	27.55
# 2018-04-19 00:00:00	54.47	54.06
# 2018-08-01 00:00:00	61.65	61.99
# 2015-11-18 00:00:00	38.0	36.35
# 2019-03-29 00:00:00	58.84	59.51
# 2022-08-23 00:00:00	113.86	114.66
# 2008-02-08 00:00:00	12.93	12.51
# 2008-05-15 00:00:00	14.54	14.23
# 2017-09-06 00:00:00	47.1	47.17
# 2008-07-31 00:00:00	11.86	11.74
# 2011-06-23 00:00:00	12.02	11.98
# 2021-05-10 00:00:00	114.59	117.13
# 2009-03-23 00:00:00	8.72	8.36
# 2015-08-10 00:00:00	33.16	33.34
# 2018-10-17 00:00:00	56.38	56.23
# 2014-02-10 00:00:00	29.35	29.44
# 2011-06-28 00:00:00	12.35	12.19
# 2018-10-15 00:00:00	55.12	55.18
# 2019-05-16 00:00:00	59.22	58.39
# 2020-10-08 00:00:00	74.17	72.76
# ...

# %% [markdown]
# ## Make prediction from user input

# %%
pred = model.predict([[datetime.timestamp(datetime.strptime(input("Enter date (dd/mm/yy): "), '%d/%m/%y')), float(input('Enter Open price: '))]])
print(f'{ticker.upper()} closing price prediction: {pred[0]}')
# Out:
# Enter date (dd/mm/yy): 6/1/23
# Enter Open price: 86.79
# GOOGL closing price prediction: 87.33999633789062
